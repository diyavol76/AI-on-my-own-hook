# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
# make the original data
N = 1000
series = np.sin(0.1*np.arange(N)) + np.random.randn(N)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y).reshape(-1, 1)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (990, 10, 1) Y.shape (990, 1)

# %%
# Set device
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
### Define simple RNN
# input is N,T,D
class SimpleRNN(nn.Module):
    def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
        super(SimpleRNN, self).__init__()
        self.D = n_inputs
        self.M = n_hidden
        self.K = n_outputs
        self.L = n_rnnlayers

        # note: batch_first=True
        # applies the convention that our data will be of shape:
        # (num_samples, sequence_length, num_features)
        # rather than:
        # (sequence_length, num_samples, num_features)
        self.rnn = nn.RNN(
            input_size=self.D,
            hidden_size=self.M,
            num_layers=self.L,
            nonlinearity='relu',
            batch_first=True)
        self.fc = nn.Linear(self.M, self.K)

    def forward(self, X):
        # initial hidden states
        h0 = torch.zeros(self.L, X.size(0), self.M).to(device)

        # get RNN unit output
        # out is of size (N, T, M)
        # 2nd return value is hidden states at each hidden layer
        # we don't need those now
        out, _ = self.rnn(X, h0)

        # we only want h(T) at the final time step
        # N x M -> N x K
        out = self.fc(out[:, -1, :])
        return out

# %%
# Instantiate the model
model = SimpleRNN(n_inputs=1, n_hidden=15, n_rnnlayers=1, n_outputs=1)
model.to(device)
# Out:
# SimpleRNN(
#   (rnn): RNN(1, 15, batch_first=True)
#   (fc): Linear(in_features=15, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Make inputs and targets
X_train = torch.from_numpy(X[:-N//2].astype(np.float32))
y_train = torch.from_numpy(Y[:-N//2].astype(np.float32))
X_test = torch.from_numpy(X[-N//2:].astype(np.float32))
y_test = torch.from_numpy(Y[-N//2:].astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
# Training
def full_gd(model,
            criterion,
            optimizer,
            X_train,
            y_train,
            X_test,
            y_test,
            epochs=1000):

    # Stuff to store
    train_losses = np.zeros(epochs)
    test_losses = np.zeros(epochs)

    for it in range(epochs):
        # zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(X_train)
        loss = criterion(outputs, y_train)

        # Backward and optimize
        loss.backward()
        optimizer.step()

        # Save losses
        train_losses[it] = loss.item()

        # Test loss
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)
        test_losses[it] = test_loss.item()

        if (it + 1) % 5 == 0:
            print(f'Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}')

    return train_losses, test_losses

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test)
# Out:
# Epoch 5/1000, Train Loss: 0.5604, Test Loss: 0.5761
# Epoch 10/1000, Train Loss: 0.5450, Test Loss: 0.5606
# Epoch 15/1000, Train Loss: 0.5315, Test Loss: 0.5467
# Epoch 20/1000, Train Loss: 0.5174, Test Loss: 0.5319
# Epoch 25/1000, Train Loss: 0.5022, Test Loss: 0.5157
# Epoch 30/1000, Train Loss: 0.4850, Test Loss: 0.4975
# Epoch 35/1000, Train Loss: 0.4655, Test Loss: 0.4766
# Epoch 40/1000, Train Loss: 0.4421, Test Loss: 0.4513
# Epoch 45/1000, Train Loss: 0.4115, Test Loss: 0.4182
# Epoch 50/1000, Train Loss: 0.3718, Test Loss: 0.3756
# Epoch 55/1000, Train Loss: 0.3244, Test Loss: 0.3261
# Epoch 60/1000, Train Loss: 0.2741, Test Loss: 0.2743
# Epoch 65/1000, Train Loss: 0.2271, Test Loss: 0.2266
# Epoch 70/1000, Train Loss: 0.1838, Test Loss: 0.1818
# Epoch 75/1000, Train Loss: 0.1428, Test Loss: 0.1399
# Epoch 80/1000, Train Loss: 0.1072, Test Loss: 0.1046
# Epoch 85/1000, Train Loss: 0.0794, Test Loss: 0.0772
# Epoch 90/1000, Train Loss: 0.0598, Test Loss: 0.0588
# Epoch 95/1000, Train Loss: 0.0491, Test Loss: 0.0493
# Epoch 100/1000, Train Loss: 0.0419, Test Loss: 0.0424
# Epoch 105/1000, Train Loss: 0.0360, Test Loss: 0.0371
# Epoch 110/1000, Train Loss: 0.0315, Test Loss: 0.0329
# Epoch 115/1000, Train Loss: 0.0270, Test Loss: 0.0285
# Epoch 120/1000, Train Loss: 0.0230, Test Loss: 0.0247
# Epoch 125/1000, Train Loss: 0.0197, Test Loss: 0.0216
# Epoch 130/1000, Train Loss: 0.0172, Test Loss: 0.0194
# Epoch 135/1000, Train Loss: 0.0157, Test Loss: 0.0179
# Epoch 140/1000, Train Loss: 0.0148, Test Loss: 0.0171
# Epoch 145/1000, Train Loss: 0.0144, Test Loss: 0.0167
# Epoch 150/1000, Train Loss: 0.0140, Test Loss: 0.0163
# Epoch 155/1000, Train Loss: 0.0139, Test Loss: 0.0161
# Epoch 160/1000, Train Loss: 0.0138, Test Loss: 0.0161
# Epoch 165/1000, Train Loss: 0.0137, Test Loss: 0.0160
# Epoch 170/1000, Train Loss: 0.0136, Test Loss: 0.0160
# Epoch 175/1000, Train Loss: 0.0136, Test Loss: 0.0161
# Epoch 180/1000, Train Loss: 0.0136, Test Loss: 0.0160
# Epoch 185/1000, Train Loss: 0.0135, Test Loss: 0.0160
# Epoch 190/1000, Train Loss: 0.0135, Test Loss: 0.0160
# Epoch 195/1000, Train Loss: 0.0135, Test Loss: 0.0160
# Epoch 200/1000, Train Loss: 0.0134, Test Loss: 0.0159
# Epoch 205/1000, Train Loss: 0.0134, Test Loss: 0.0159
# Epoch 210/1000, Train Loss: 0.0134, Test Loss: 0.0158
# Epoch 215/1000, Train Loss: 0.0133, Test Loss: 0.0158
# Epoch 220/1000, Train Loss: 0.0133, Test Loss: 0.0158
# Epoch 225/1000, Train Loss: 0.0132, Test Loss: 0.0157
# Epoch 230/1000, Train Loss: 0.0132, Test Loss: 0.0157
# Epoch 235/1000, Train Loss: 0.0131, Test Loss: 0.0156
# Epoch 240/1000, Train Loss: 0.0131, Test Loss: 0.0156
# Epoch 245/1000, Train Loss: 0.0131, Test Loss: 0.0156
# Epoch 250/1000, Train Loss: 0.0131, Test Loss: 0.0155
# Epoch 255/1000, Train Loss: 0.0131, Test Loss: 0.0155
# Epoch 260/1000, Train Loss: 0.0131, Test Loss: 0.0155
# Epoch 265/1000, Train Loss: 0.0131, Test Loss: 0.0155
# Epoch 270/1000, Train Loss: 0.0130, Test Loss: 0.0155
# Epoch 275/1000, Train Loss: 0.0130, Test Loss: 0.0155
# Epoch 280/1000, Train Loss: 0.0130, Test Loss: 0.0155
# Epoch 285/1000, Train Loss: 0.0130, Test Loss: 0.0155
# Epoch 290/1000, Train Loss: 0.0130, Test Loss: 0.0155
# Epoch 295/1000, Train Loss: 0.0130, Test Loss: 0.0155
# Epoch 300/1000, Train Loss: 0.0130, Test Loss: 0.0154
# Epoch 305/1000, Train Loss: 0.0130, Test Loss: 0.0154
# Epoch 310/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 315/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 320/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 325/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 330/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 335/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 340/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 345/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 350/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 355/1000, Train Loss: 0.0129, Test Loss: 0.0154
# Epoch 360/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 365/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 370/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 375/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 380/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 385/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 390/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 395/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 400/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 405/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 410/1000, Train Loss: 0.0128, Test Loss: 0.0154
# Epoch 415/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 420/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 425/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 430/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 435/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 440/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 445/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 450/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 455/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 460/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 465/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 470/1000, Train Loss: 0.0127, Test Loss: 0.0154
# Epoch 475/1000, Train Loss: 0.0127, Test Loss: 0.0153
# Epoch 480/1000, Train Loss: 0.0127, Test Loss: 0.0153
# Epoch 485/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 490/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 495/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 500/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 505/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 510/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 515/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 520/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 525/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 530/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 535/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 540/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 545/1000, Train Loss: 0.0126, Test Loss: 0.0153
# Epoch 550/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 555/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 560/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 565/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 570/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 575/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 580/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 585/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 590/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 595/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 600/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 605/1000, Train Loss: 0.0125, Test Loss: 0.0153
# Epoch 610/1000, Train Loss: 0.0125, Test Loss: 0.0152
# Epoch 615/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 620/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 625/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 630/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 635/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 640/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 645/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 650/1000, Train Loss: 0.0124, Test Loss: 0.0152
# Epoch 655/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 660/1000, Train Loss: 0.0124, Test Loss: 0.0152
# Epoch 665/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 670/1000, Train Loss: 0.0124, Test Loss: 0.0153
# Epoch 675/1000, Train Loss: 0.0124, Test Loss: 0.0152
# Epoch 680/1000, Train Loss: 0.0124, Test Loss: 0.0152
# Epoch 685/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 690/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 695/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 700/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 705/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 710/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 715/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 720/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 725/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 730/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 735/1000, Train Loss: 0.0123, Test Loss: 0.0151
# Epoch 740/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 745/1000, Train Loss: 0.0123, Test Loss: 0.0152
# Epoch 750/1000, Train Loss: 0.0123, Test Loss: 0.0151
# Epoch 755/1000, Train Loss: 0.0123, Test Loss: 0.0151
# Epoch 760/1000, Train Loss: 0.0123, Test Loss: 0.0151
# Epoch 765/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 770/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 775/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 780/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 785/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 790/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 795/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 800/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 805/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 810/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 815/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 820/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 825/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 830/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 835/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 840/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 845/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 850/1000, Train Loss: 0.0122, Test Loss: 0.0151
# Epoch 855/1000, Train Loss: 0.0122, Test Loss: 0.0152
# Epoch 860/1000, Train Loss: 0.0121, Test Loss: 0.0152
# Epoch 865/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 870/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 875/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 880/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 885/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 890/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 895/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 900/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 905/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 910/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 915/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 920/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 925/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 930/1000, Train Loss: 0.0121, Test Loss: 0.0151
# Epoch 935/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 940/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 945/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 950/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 955/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 960/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 965/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 970/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 975/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 980/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 985/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 990/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 995/1000, Train Loss: 0.0120, Test Loss: 0.0151
# Epoch 1000/1000, Train Loss: 0.0120, Test Loss: 0.0151

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = 0

while len(validation_predictions) < len(validation_target):
    input_ = X_test[i].reshape(1, T, 1)
    p = model(input_)[0,0].item() # 1x1 array -> scalar
    i += 1

    # update the predictions list
    validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# last train input
# last_x = torch.from_numpy(X[-N//2]) # 1-D array of length T
# last_x = torch.from_numpy(X[-N//2].astype(np.float32))
last_x = X_test[0].view(T)

while len(validation_predictions) < len(validation_target):
    input_ = last_x.reshape(1, T, 1)
    p = model(input_)
    # [0,0] # 1x1 array -> scalar

    # update the predictions list
    validation_predictions.append(p[0,0].item())

    # make the new input
    last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
